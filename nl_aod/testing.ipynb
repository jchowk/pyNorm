# %%
# %run xlimit

# %%
x = np.arange(-300.,200.,0.35)
xpos1 = -50.
xpos2 = +100.

# %%
x1, x2 = xlimit(x, xpos1, xpos2)

# %%
x1,x2
# Out:
# (714, 1143)

# %%
x[[x1,x2]]
# Out:
# array([-50.1 , 100.05])

# %%
x[x1:(x2)+1]
# Out:
# array([-5.0100e+01, -4.9750e+01, -4.9400e+01, -4.9050e+01, -4.8700e+01,
#        -4.8350e+01, -4.8000e+01, -4.7650e+01, -4.7300e+01, -4.6950e+01,
#        -4.6600e+01, -4.6250e+01, -4.5900e+01, -4.5550e+01, -4.5200e+01,
#        -4.4850e+01, -4.4500e+01, -4.4150e+01, -4.3800e+01, -4.3450e+01,
#        -4.3100e+01, -4.2750e+01, -4.2400e+01, -4.2050e+01, -4.1700e+01,
#        -4.1350e+01, -4.1000e+01, -4.0650e+01, -4.0300e+01, -3.9950e+01,
#        -3.9600e+01, -3.9250e+01, -3.8900e+01, -3.8550e+01, -3.8200e+01,
#        -3.7850e+01, -3.7500e+01, -3.7150e+01, -3.6800e+01, -3.6450e+01,
#        -3.6100e+01, -3.5750e+01, -3.5400e+01, -3.5050e+01, -3.4700e+01,
#        -3.4350e+01, -3.4000e+01, -3.3650e+01, -3.3300e+01, -3.2950e+01,
#        -3.2600e+01, -3.2250e+01, -3.1900e+01, -3.1550e+01, -3.1200e+01,
#        -3.0850e+01, -3.0500e+01, -3.0150e+01, -2.9800e+01, -2.9450e+01,
#        -2.9100e+01, -2.8750e+01, -2.8400e+01, -2.8050e+01, -2.7700e+01,
# ...
